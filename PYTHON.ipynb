# %% [markdown]
# <a href="https://colab.research.google.com/github/monica-s-araujo/Estudos-Gerais/blob/main/PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lista = ['Fabricio Daniel',9.9,7.0,8.0,True]
lista
# Out:
# ['Fabricio Daniel', 9.9, 7.0, 8.0, True]

# %%
lista[0]
# Out:
# 'Fabricio Daniel'

# %%
lista[-5]
# Out:
# 'Fabricio Daniel'
