# %% [markdown]
# 1) Escreva um programa que peça à pessoa usuária para fornecer dois números e exibir o número maior.

# %%
Prim= int(input("Digite o primeiro número: "))
Seg= int(input("Digite o segundo número: "))
if Prim > Seg:
    print(f"O número maior é: {Prim}")
else:
    print(f"O número maior é: {Seg}")
# Out:
# Digite o primeiro número: 1
# Digite o segundo número: 3
# O número maior é: 3

# %% [markdown]
# 2) Escreva um programa que solicite o percentual de crescimento de produção de uma empresa e informe se houve um crescimento (porcentagem positiva) ou decrescimento (porcentagem negativa).

# %%
per= float(input("Digite o percentual de crescimento: "))
if per > 0:
    print("Houve um crescimento")
else:
    print("Houve um decrescimento")
# Out:
# Digite o percentual de crescimento: -25
# Houve um decrescimento

# %% [markdown]
# 3) Escreva um programa que determine se uma letra fornecida pela pessoa usuária é uma vogal ou consoante.

# %%
letra= input("Digite uma letra: ")
if letra == "a" or letra == "e" or letra == "i" or letra == "o" or letra == "u":
    print("É uma vogal")
else:
    print("É uma consoante")
# Out:
# Digite uma letra: m
# É uma consoante

# %% [markdown]
# 4) Escreva um programa que leia valores médios de preços de um modelo de carro por 3 anos consecutivos e exiba o valor mais alto e mais baixo entre esses três anos.

# %%
pm= float(input("Digite o preço médio do modelo do carro no primeiro ano: "))
sm= float(input("Digite o preço médio do modelo do carro no segundo ano: "))
tm= float(input("Digite o preço médio do modelo do carro no terceiro ano: "))
# Out:
# Digite o preço médio do modelo do carro no primeiro ano: 15000
# Digite o preço médio do modelo do carro no segundo ano: 16555
# Digite o preço médio do modelo do carro no terceiro ano: 23000

# %%
if pm > sm and pm > tm:
    print(f"O maior preço médio foi no PRIMEIRO ano: {pm}")
elif sm > pm and sm > tm:
    print(f"O maior preço médio foi no SEGUNDO ano: {sm}")
else:
    print(f"O maior preço médio foi no TERCEIRO ano: {tm}")
# Out:
# O maior preço médio foi no TERCEIRO ano: 23000.0

# %% [markdown]
# 5) Escreva um programa que pergunte sobre o preço de três produtos e indique qual é o produto mais barato para comprar.

# %%
pp= float(input("Digite o preço do primeiro produto: "))
sp= float(input("Digite o preço do segundo produto: "))
tp= float(input("Digite o preço do terceiro produto: "))
# Out:
# Digite o preço do primeiro produto: 65
# Digite o preço do segundo produto: 35
# Digite o preço do terceiro produto: 1

# %%
if pp < sp and pp < tp:
    print(f"O primeiro produto é o mais barato: {pp}")
elif sp < pp and sp < tp:
    print(f"O segundo produto é o mais barato: {sp}")
else:
   print(f"o terceiro é o mais barato:  {tp}" )
# Out:
# o terceiro é o mais barato:  1.0

# %%
produtos = {
    "Primeiro produto": pp,
    "Segundo produto": sp,
    "Terceiro produto": tp
}

mais_barato = min(produtos, key=produtos.get)
print(f"{mais_barato} é o mais barato: {produtos[mais_barato]}")
# Out:
# Terceiro produto é o mais barato: 1.0

# %% [markdown]
# 6) Escreva um programa que leia três números e os exiba em ordem decrescente.

# %%
n1= int(input("Digite o primeiro número: "))
n2= int(input("Digite o segundo número: "))
n3= int(input("Digite o terceiro número: "))
# Out:
# Digite o primeiro número: 896
# Digite o segundo número: 458
# Digite o terceiro número: 965

# %%
numeros = [n1, n2, n3]
numeros.sort(reverse=True)

print("Números em ordem decrescente:", numeros)
# Out:
# Números em ordem decrescente: [965, 896, 458]

# %%
if n1 >= n2 and n1 >= n3:
    if n2 >= n3:
        print(n1, n2, n3)
    else:
        print(n1, n3, n2)
elif n2 >= n1 and n2 >= n3:
    if n1 >= n3:
        print(n2, n1, n3)
    else:
        print(n2, n3, n1)
else:
    if n1 >= n2:
        print(n3, n1, n2)
    else:
        print(n3, n2, n1)
# Out:
# 965 896 458

# %% [markdown]
# 7) Escreva um programa que pergunte em qual turno a pessoa usuária estuda ("manhã", "tarde" ou "noite") e exiba a mensagem "Bom Dia!", "Boa Tarde!", "Boa Noite!", ou "Valor Inválido!", conforme o caso.

# %%
periodo= str(input("Em qual período você estuda? "))
if periodo == "manhã":
    print("Bom Dia!")
elif periodo == "tarde":
    print("Boa Tarde!")
elif periodo == "noite":
    print("Boa Noite!")
# Out:
# Em qual período você estuda? manhã
# Bom Dia!

# %% [markdown]
# 8) Escreva um programa que peça um número inteiro à pessoa usuária e determine se ele é par ou ímpar. Dica: Você pode utilizar o operador módulo %.

# %%
n= int(input("Digite um número inteiro: "))
if n % 2 == 0:
    print("O número é par")
else:
    print("O número é ímpar")
# Out:
# Digite um número inteiro: 52
# O número é par

# %% [markdown]
# 9) Escreva um programa que peça um número à pessoa usuária e informe se ele é inteiro ou decimal.

# %%
num= float(input("Digite um número: "))
if num.is_integer():
    print("O número é inteiro")
else:
    print("O número é decimal")
# Out:
# Digite um número: 1
# O número é inteiro

# %% [markdown]
# 10) Um programa deve ser escrito para ler dois números e, em seguida, perguntar à pessoa usuária qual operação ele deseja realizar. O resultado da operação deve incluir informações sobre o número - se é par ou ímpar, positivo ou negativo e inteiro ou decimal.

# %%
n1 = float(input("Digite o primeiro número: "))
n2 = float(input("Digite o segundo número: "))

print("Escolha a operação:")
print("+ para soma")
print("- para subtração")
print("* para multiplicação")
print("/ para divisão")

op= input("Digite a operação que deseja realizar: ")
if op == "+":
    resultado = n1 + n2
elif op== "-":
    resultado = n1 - n2
elif op == "*":
    resultado = n1 * n2
elif op == "/":
  if n2 == 0:
    print("Não é possível dividir por zero")
  else:
    resultado = n1 / n2
else:
    print("Operação inválida")
print(f"O resultado da operação é: {resultado}")
if resultado % 2 == 0:
    print("O número é par")
else:
    print("O número é ímpar")
    if resultado > 0:
        print("O número é positivo")
    else:
        print("O número é negativo")
    if resultado.is_integer():
        print("O número é inteiro")
    else:
        print("O número é decimal")
# Out:
# Digite o primeiro número: 25
# Digite o segundo número: 36
# Escolha a operação:
# + para soma
# - para subtração
# * para multiplicação
# / para divisão
# Digite a operação que deseja realizar: +
# O resultado da operação é: 61.0
# O número é ímpar
# O número é positivo
# O número é inteiro

# %% [markdown]
# 11) Escreva um programa que peça à pessoa usuária três números que representam os lados de um triângulo. O programa deve informar se os valores podem ser utilizados para formar um triângulo e, caso afirmativo, se ele é equilátero, isósceles ou escaleno. Tenha em mente algumas dicas:
#
# Três lados formam um triângulo quando a soma de quaisquer dois lados for maior que o terceiro;
# Triângulo Equilátero: três lados iguais;
# Triângulo Isósceles: quaisquer dois lados iguais;
# Triângulo Escaleno: três lados diferentes.

# %%
n1 = float(input("Digite o primeiro número: "))
n2 = float(input("Digite o segundo número: "))
n3 = float(input("Digite o terceiro número: "))
if n1 + n2 > n3 or n1 + n3 > n2 or n2 + n3 > n1:
  print ("É um triângulo")
  if n1 == n2 == n3:
    print("É um triângulo equilátero")
  elif n1 == n2 or n1 == n3 or n2 == n3:
    print("É um triângulo isósceles")
  else:
    print("É um triângulo escaleno")
else:
    print("Não é um triângulo")
# Out:
# Digite o primeiro número: 56
# Digite o segundo número: 56
# Digite o terceiro número: 25
# É um triângulo
# É um triângulo isósceles

# %% [markdown]
# 12) Um estabelecimento está vendendo combustíveis com descontos variados. Para o etanol, se a quantidade comprada for até 15 litros, o desconto será de 2% por litro. Caso contrário, será de 4% por litro. Para o diesel, se a quantidade comprada for até 15 litros, o desconto será de 3% por litro. Caso contrário, será de 5% por litro. O preço do litro de diesel é R$ 2,00 e o preço do litro de etanol é R$ 1,70. Escreva um programa que leia a quantidade de litros vendidos e o tipo de combustível (E para etanol e D para diesel) e calcule o valor a ser pago pelo cliente. Tenha em mente algumas dicas:
#
# O do valor do desconto será a multiplicação entre preço do litro, quantidade de litros e o valor do desconto.
# O valor a ser pago por um cliente será o resultado da multiplicação do preço do litro pela quantidade de litros menos o valor de desconto resultante do cálculo.

# %%
litros = float(input("Digite a quantidade de litros vendidos: "))
tipo = str(input("Digite o tipo de combustível (E para etanol e D para diesel): ")).upper()
if tipo == "E":
    preco_litro = 1.70
    if litros <= 15:
      preco_litro = 1.70 - (1.70 * 0.02)
    else:
      preco_litro = 1.70 - (1.70 * 0.04)

elif tipo == "D":
    preco_litro = 2.00
    if litros <= 15:
      preco_litro = 2.00 - (2.00 * 0.03)
    else:
      preco_litro = 2.00 - (2.0 * 0.04)

else:
  print("Tipo de combustível inválido!")
  preco_litro = 0

total = litros * preco_litro
print(f"Valor a pagar: R$ {total:.2f}")
# Out:
# Digite a quantidade de litros vendidos: 15
# Digite o tipo de combustível (E para etanol e D para diesel): D
# Valor a pagar: R$ 29.10

# %% [markdown]
# 13) Em uma empresa de venda de imóveis você precisa criar um código que analise os dados de vendas anuais para ajudar a diretoria na tomada de decisão. O código precisa coletar os dados de quantidade de venda durante os anos de 2022 e 2023 e fazer um cálculo de variação percentual. A partir do valor da variação, deve ser enviada às seguintes sugestões:
#
# Para variação acima de 20%: bonificação para o time de vendas.
# Para variação entre 2% e 20%: pequena bonificação para time de vendas.
# Para variação entre 2% e -10%: planejamento de políticas de incentivo às vendas.
# Para variação abaixo de -10%: corte de gastos.

# %%
ano1= float(input("Digite a quantidade de vendas em 2022: "))
ano2= float(input("Digite a quantidade de vendas em 2023: "))
var= (ano2 - ano1) / ano2 * 100
if var > 20:
    print("Bonificação para o time de vendas")
elif var >= 2 and var <= 20:
        print("Pequena bonificação para time de vendas")
elif var >= -10 and var < 2:
        print("Planejamento de políticas de incentivo às vendas")
elif var < -10:
        print("Corte de gastos")
else:
            print("Variação inválida")
# Out:
# Digite a quantidade de vendas em 2022: 10
# Digite a quantidade de vendas em 2023: 10
# Planejamento de políticas de incentivo às vendas
